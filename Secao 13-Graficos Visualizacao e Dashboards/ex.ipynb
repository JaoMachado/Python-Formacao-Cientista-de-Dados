# %%
import pandas as pd
import seaborn as srn
import statistics as sts
import matplotlib.pyplot as plt

# %%
base = pd.read_csv("dados.csv", sep=";")
base
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 0       106    SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1       113             SANTO ANGELO  16575.82     800669.92
# 2       118   SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3        13          CACAPAVA DO SUL  13674.54     485535.86
# 4       120              SAO GABRIEL  19912.38     533719.86
# ..      ...                      ...       ...           ...
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# 184      54           GETULIO VARGAS  16876.33        233.01
# 185     382          NOVA SANTA RITA  25938.38        310.58
# 186      60      GUARANI DAS MISSOES  24363.31        172.13
#
# [187 rows x 4 columns]

# %%
srn.histplot(base.PIB, kde=True, bins=15)
# Out:
# <Axes: xlabel='PIB', ylabel='Count'>

# %%
srn.histplot(base.VALOREMPENHO, kde=True, bins=15)
# Out:
# <Axes: xlabel='VALOREMPENHO', ylabel='Count'>

# %%
agrupado = base.sort_values('PIB').head(10)
agrupado = agrupado.iloc[:,1:3]
agrupado
# Out:
#                MUNICIPIO       PIB
# 88             REDENTORA   8236.63
# 11       AMARAL FERRADOR   9216.87
# 15   ENCRUZILHADA DO SUL  10372.80
# 66      SENTINELA DO SUL  10477.52
# 89    SAO VALERIO DO SUL  10503.72
# 6               PIRATINI  10811.67
# 56                  MATA  10935.82
# 37  SANTANA DA BOA VISTA  11172.34
# 16               CANGUCU  11213.34
# 47             JAQUIRANA  11413.37

# %%
agrupado.plot.bar('MUNICIPIO', 'PIB')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
agrupado = base.groupby('MUNICIPIO')['VALOREMPENHO'].sum()
agrupado
# Out:
# MUNICIPIO
# AGUDO                         134912.00
# AJURICABA                     180603.16
# ALECRIM                        70277.71
# ALMIRANTE TAMANDARE DO SUL     31936.85
# ALTO FELIZ                     82293.86
#                                 ...
# VERA CRUZ                     246386.96
# VIADUTOS                       38128.96
# VICTOR GRAEFF                  79029.29
# VILA MARIA                     28149.89
# VILA NOVA DO SUL              141895.69
# Name: VALOREMPENHO, Length: 177, dtype: float64

# %%
agrupado = agrupado[0:20]
agrupado.plot.bar('MUNICIPIO', 'VALOREMPENHO', color='black')
# Out:
# <Axes: xlabel='MUNICIPIO'>
